# %% [markdown]
# <a href="https://colab.research.google.com/github/Sogum0503/LikeLion_DataSchool/blob/main/PYTHON/0502_%EB%B0%98%EB%B3%B5%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 반복문
#
# * 반복문을 사용하는 이유 -> 업무의 최소화, 빠른 퇴근, 나의 체력 안배
#
# 특히 데이터 분석에서는
# * 월별/분기별/연도별 산출할 게 있을 경우
# * 컬럼별 데이터 검사 및 특이값 이상치 발견
# * Rule Base 최적 상품 추천
# * ML/DL모델을 파라미터를 바꿔서 반복 시행할때
# * 기타 3번 이상 반복 작업 해야하는 반복되는 일들
#
# 에서 사용되게 됩니다.

# %%
#  For 반복문 기초 1 

for x in (1,2,3,4,5):
  print(f"{x}번째 입니다.")
# Out:
# 1번째 입니다.
# 2번째 입니다.
# 3번째 입니다.
# 4번째 입니다.
# 5번째 입니다.

# %%
# For 반복문 기초

문자열 = 'hello world'

for a in 문자열:
  print(a)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
# 리스트를 범위로 지정한 예시

list_a = ['하나','둘','셋','넷','다섯']

for a in list_a:
  print(a)
# Out:
# 하나
# 둘
# 셋
# 넷
# 다섯

# %%
dict_a = {'하나': 'one',
            '둘' : 'two',
            '셋' : 'three'
          }

for a in dict_a.items(): # items 안하면 key값만 나온다 
  print(a)
# Out:
# ('하나', 'one')
# ('둘', 'two')
# ('셋', 'three')

# %%
# range 1번 예시 

for a in range(0, 5, 1):
  print(a)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# range 2번 예시 

for a in range(0, 10, 2):
  print(a)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# 반복문 기초 

from time import process_time 

start = process_time()

# 1,000,000 ~ 하루 / 이틀 / 일주일
for i in range(1, 1000):
  print(f"숫자를 출력합니다. {i}")

end = process_time()
print(f'프로그램을 수행하는데 {end - start}초가 걸렸습니다')
# Out:
# 숫자를 출력합니다. 1
# 숫자를 출력합니다. 2
# 숫자를 출력합니다. 3
# 숫자를 출력합니다. 4
# 숫자를 출력합니다. 5
# 숫자를 출력합니다. 6
# 숫자를 출력합니다. 7
# 숫자를 출력합니다. 8
# 숫자를 출력합니다. 9
# 숫자를 출력합니다. 10
# 숫자를 출력합니다. 11
# 숫자를 출력합니다. 12
# 숫자를 출력합니다. 13
# 숫자를 출력합니다. 14
# 숫자를 출력합니다. 15
# 숫자를 출력합니다. 16
# 숫자를 출력합니다. 17
# 숫자를 출력합니다. 18
# 숫자를 출력합니다. 19
# 숫자를 출력합니다. 20
# 숫자를 출력합니다. 21
# 숫자를 출력합니다. 22
# 숫자를 출력합니다. 23
# 숫자를 출력합니다. 24
# 숫자를 출력합니다. 25
# 숫자를 출력합니다. 26
# 숫자를 출력합니다. 27
# 숫자를 출력합니다. 28
# 숫자를 출력합니다. 29
# 숫자를 출력합니다. 30
# 숫자를 출력합니다. 31
# 숫자를 출력합니다. 32
# 숫자를 출력합니다. 33
# 숫자를 출력합니다. 34
# 숫자를 출력합니다. 35
# 숫자를 출력합니다. 36
# 숫자를 출력합니다. 37
# 숫자를 출력합니다. 38
# 숫자를 출력합니다. 39
# 숫자를 출력합니다. 40
# 숫자를 출력합니다. 41
# 숫자를 출력합니다. 42
# 숫자를 출력합니다. 43
# 숫자를 출력합니다. 44
# 숫자를 출력합니다. 45
# 숫자를 출력합니다. 46
# 숫자를 출력합니다. 47
# 숫자를 출력합니다. 48
# 숫자를 출력합니다. 49
# 숫자를 출력합니다. 50
# 숫자를 출력합니다. 51
# 숫자를 출력합니다. 52
# 숫자를 출력합니다. 53
# 숫자를 출력합니다. 54
# 숫자를 출력합니다. 55
# 숫자를 출력합니다. 56
# 숫자를 출력합니다. 57
# 숫자를 출력합니다. 58
# 숫자를 출력합니다. 59
# 숫자를 출력합니다. 60
# 숫자를 출력합니다. 61
# 숫자를 출력합니다. 62
# 숫자를 출력합니다. 63
# 숫자를 출력합니다. 64
# 숫자를 출력합니다. 65
# 숫자를 출력합니다. 66
# 숫자를 출력합니다. 67
# 숫자를 출력합니다. 68
# 숫자를 출력합니다. 69
# 숫자를 출력합니다. 70
# 숫자를 출력합니다. 71
# 숫자를 출력합니다. 72
# 숫자를 출력합니다. 73
# 숫자를 출력합니다. 74
# 숫자를 출력합니다. 75
# 숫자를 출력합니다. 76
# 숫자를 출력합니다. 77
# 숫자를 출력합니다. 78
# 숫자를 출력합니다. 79
# 숫자를 출력합니다. 80
# 숫자를 출력합니다. 81
# 숫자를 출력합니다. 82
# 숫자를 출력합니다. 83
# 숫자를 출력합니다. 84
# 숫자를 출력합니다. 85
# 숫자를 출력합니다. 86
# 숫자를 출력합니다. 87
# 숫자를 출력합니다. 88
# 숫자를 출력합니다. 89
# 숫자를 출력합니다. 90
# 숫자를 출력합니다. 91
# 숫자를 출력합니다. 92
# 숫자를 출력합니다. 93
# 숫자를 출력합니다. 94
# 숫자를 출력합니다. 95
# 숫자를 출력합니다. 96
# 숫자를 출력합니다. 97
# 숫자를 출력합니다. 98
# 숫자를 출력합니다. 99
# 숫자를 출력합니다. 100
# 숫자를 출력합니다. 101
# 숫자를 출력합니다. 102
# 숫자를 출력합니다. 103
# 숫자를 출력합니다. 104
# 숫자를 출력합니다. 105
# 숫자를 출력합니다. 106
# 숫자를 출력합니다. 107
# 숫자를 출력합니다. 108
# 숫자를 출력합니다. 109
# 숫자를 출력합니다. 110
# 숫자를 출력합니다. 111
# 숫자를 출력합니다. 112
# 숫자를 출력합니다. 113
# 숫자를 출력합니다. 114
# 숫자를 출력합니다. 115
# 숫자를 출력합니다. 116
# 숫자를 출력합니다. 117
# 숫자를 출력합니다. 118
# 숫자를 출력합니다. 119
# 숫자를 출력합니다. 120
# 숫자를 출력합니다. 121
# 숫자를 출력합니다. 122
# 숫자를 출력합니다. 123
# 숫자를 출력합니다. 124
# 숫자를 출력합니다. 125
# 숫자를 출력합니다. 126
# 숫자를 출력합니다. 127
# 숫자를 출력합니다. 128
# 숫자를 출력합니다. 129
# 숫자를 출력합니다. 130
# 숫자를 출력합니다. 131
# 숫자를 출력합니다. 132
# 숫자를 출력합니다. 133
# 숫자를 출력합니다. 134
# 숫자를 출력합니다. 135
# 숫자를 출력합니다. 136
# 숫자를 출력합니다. 137
# 숫자를 출력합니다. 138
# 숫자를 출력합니다. 139
# 숫자를 출력합니다. 140
# 숫자를 출력합니다. 141
# 숫자를 출력합니다. 142
# 숫자를 출력합니다. 143
# 숫자를 출력합니다. 144
# 숫자를 출력합니다. 145
# 숫자를 출력합니다. 146
# 숫자를 출력합니다. 147
# 숫자를 출력합니다. 148
# 숫자를 출력합니다. 149
# 숫자를 출력합니다. 150
# 숫자를 출력합니다. 151
# 숫자를 출력합니다. 152
# 숫자를 출력합니다. 153
# 숫자를 출력합니다. 154
# 숫자를 출력합니다. 155
# 숫자를 출력합니다. 156
# 숫자를 출력합니다. 157
# 숫자를 출력합니다. 158
# 숫자를 출력합니다. 159
# 숫자를 출력합니다. 160
# 숫자를 출력합니다. 161
# 숫자를 출력합니다. 162
# 숫자를 출력합니다. 163
# 숫자를 출력합니다. 164
# 숫자를 출력합니다. 165
# 숫자를 출력합니다. 166
# 숫자를 출력합니다. 167
# 숫자를 출력합니다. 168
# 숫자를 출력합니다. 169
# 숫자를 출력합니다. 170
# 숫자를 출력합니다. 171
# 숫자를 출력합니다. 172
# 숫자를 출력합니다. 173
# 숫자를 출력합니다. 174
# 숫자를 출력합니다. 175
# 숫자를 출력합니다. 176
# 숫자를 출력합니다. 177
# 숫자를 출력합니다. 178
# 숫자를 출력합니다. 179
# 숫자를 출력합니다. 180
# 숫자를 출력합니다. 181
# 숫자를 출력합니다. 182
# 숫자를 출력합니다. 183
# 숫자를 출력합니다. 184
# 숫자를 출력합니다. 185
# 숫자를 출력합니다. 186
# 숫자를 출력합니다. 187
# 숫자를 출력합니다. 188
# 숫자를 출력합니다. 189
# 숫자를 출력합니다. 190
# 숫자를 출력합니다. 191
# 숫자를 출력합니다. 192
# 숫자를 출력합니다. 193
# 숫자를 출력합니다. 194
# 숫자를 출력합니다. 195
# 숫자를 출력합니다. 196
# 숫자를 출력합니다. 197
# 숫자를 출력합니다. 198
# 숫자를 출력합니다. 199
# 숫자를 출력합니다. 200
# 숫자를 출력합니다. 201
# 숫자를 출력합니다. 202
# 숫자를 출력합니다. 203
# 숫자를 출력합니다. 204
# 숫자를 출력합니다. 205
# 숫자를 출력합니다. 206
# 숫자를 출력합니다. 207
# 숫자를 출력합니다. 208
# 숫자를 출력합니다. 209
# 숫자를 출력합니다. 210
# 숫자를 출력합니다. 211
# 숫자를 출력합니다. 212
# 숫자를 출력합니다. 213
# 숫자를 출력합니다. 214
# 숫자를 출력합니다. 215
# 숫자를 출력합니다. 216
# 숫자를 출력합니다. 217
# 숫자를 출력합니다. 218
# 숫자를 출력합니다. 219
# 숫자를 출력합니다. 220
# 숫자를 출력합니다. 221
# 숫자를 출력합니다. 222
# 숫자를 출력합니다. 223
# 숫자를 출력합니다. 224
# 숫자를 출력합니다. 225
# 숫자를 출력합니다. 226
# 숫자를 출력합니다. 227
# 숫자를 출력합니다. 228
# 숫자를 출력합니다. 229
# 숫자를 출력합니다. 230
# 숫자를 출력합니다. 231
# 숫자를 출력합니다. 232
# 숫자를 출력합니다. 233
# 숫자를 출력합니다. 234
# 숫자를 출력합니다. 235
# 숫자를 출력합니다. 236
# 숫자를 출력합니다. 237
# 숫자를 출력합니다. 238
# 숫자를 출력합니다. 239
# 숫자를 출력합니다. 240
# 숫자를 출력합니다. 241
# 숫자를 출력합니다. 242
# 숫자를 출력합니다. 243
# 숫자를 출력합니다. 244
# 숫자를 출력합니다. 245
# 숫자를 출력합니다. 246
# 숫자를 출력합니다. 247
# 숫자를 출력합니다. 248
# 숫자를 출력합니다. 249
# 숫자를 출력합니다. 250
# 숫자를 출력합니다. 251
# 숫자를 출력합니다. 252
# 숫자를 출력합니다. 253
# 숫자를 출력합니다. 254
# 숫자를 출력합니다. 255
# 숫자를 출력합니다. 256
# 숫자를 출력합니다. 257
# 숫자를 출력합니다. 258
# 숫자를 출력합니다. 259
# 숫자를 출력합니다. 260
# 숫자를 출력합니다. 261
# 숫자를 출력합니다. 262
# 숫자를 출력합니다. 263
# 숫자를 출력합니다. 264
# 숫자를 출력합니다. 265
# 숫자를 출력합니다. 266
# 숫자를 출력합니다. 267
# 숫자를 출력합니다. 268
# 숫자를 출력합니다. 269
# 숫자를 출력합니다. 270
# 숫자를 출력합니다. 271
# 숫자를 출력합니다. 272
# 숫자를 출력합니다. 273
# 숫자를 출력합니다. 274
# 숫자를 출력합니다. 275
# 숫자를 출력합니다. 276
# 숫자를 출력합니다. 277
# 숫자를 출력합니다. 278
# 숫자를 출력합니다. 279
# 숫자를 출력합니다. 280
# 숫자를 출력합니다. 281
# 숫자를 출력합니다. 282
# 숫자를 출력합니다. 283
# 숫자를 출력합니다. 284
# 숫자를 출력합니다. 285
# 숫자를 출력합니다. 286
# 숫자를 출력합니다. 287
# 숫자를 출력합니다. 288
# 숫자를 출력합니다. 289
# 숫자를 출력합니다. 290
# 숫자를 출력합니다. 291
# 숫자를 출력합니다. 292
# 숫자를 출력합니다. 293
# 숫자를 출력합니다. 294
# 숫자를 출력합니다. 295
# 숫자를 출력합니다. 296
# 숫자를 출력합니다. 297
# 숫자를 출력합니다. 298
# 숫자를 출력합니다. 299
# 숫자를 출력합니다. 300
# 숫자를 출력합니다. 301
# 숫자를 출력합니다. 302
# 숫자를 출력합니다. 303
# 숫자를 출력합니다. 304
# 숫자를 출력합니다. 305
# 숫자를 출력합니다. 306
# 숫자를 출력합니다. 307
# 숫자를 출력합니다. 308
# 숫자를 출력합니다. 309
# 숫자를 출력합니다. 310
# 숫자를 출력합니다. 311
# 숫자를 출력합니다. 312
# 숫자를 출력합니다. 313
# 숫자를 출력합니다. 314
# 숫자를 출력합니다. 315
# 숫자를 출력합니다. 316
# 숫자를 출력합니다. 317
# 숫자를 출력합니다. 318
# 숫자를 출력합니다. 319
# 숫자를 출력합니다. 320
# 숫자를 출력합니다. 321
# 숫자를 출력합니다. 322
# 숫자를 출력합니다. 323
# 숫자를 출력합니다. 324
# 숫자를 출력합니다. 325
# 숫자를 출력합니다. 326
# 숫자를 출력합니다. 327
# 숫자를 출력합니다. 328
# 숫자를 출력합니다. 329
# 숫자를 출력합니다. 330
# 숫자를 출력합니다. 331
# 숫자를 출력합니다. 332
# 숫자를 출력합니다. 333
# 숫자를 출력합니다. 334
# 숫자를 출력합니다. 335
# 숫자를 출력합니다. 336
# 숫자를 출력합니다. 337
# 숫자를 출력합니다. 338
# 숫자를 출력합니다. 339
# 숫자를 출력합니다. 340
# 숫자를 출력합니다. 341
# 숫자를 출력합니다. 342
# 숫자를 출력합니다. 343
# 숫자를 출력합니다. 344
# 숫자를 출력합니다. 345
# 숫자를 출력합니다. 346
# 숫자를 출력합니다. 347
# 숫자를 출력합니다. 348
# 숫자를 출력합니다. 349
# 숫자를 출력합니다. 350
# 숫자를 출력합니다. 351
# 숫자를 출력합니다. 352
# 숫자를 출력합니다. 353
# 숫자를 출력합니다. 354
# 숫자를 출력합니다. 355
# 숫자를 출력합니다. 356
# 숫자를 출력합니다. 357
# 숫자를 출력합니다. 358
# 숫자를 출력합니다. 359
# 숫자를 출력합니다. 360
# 숫자를 출력합니다. 361
# 숫자를 출력합니다. 362
# 숫자를 출력합니다. 363
# 숫자를 출력합니다. 364
# 숫자를 출력합니다. 365
# 숫자를 출력합니다. 366
# 숫자를 출력합니다. 367
# 숫자를 출력합니다. 368
# 숫자를 출력합니다. 369
# 숫자를 출력합니다. 370
# 숫자를 출력합니다. 371
# 숫자를 출력합니다. 372
# 숫자를 출력합니다. 373
# 숫자를 출력합니다. 374
# 숫자를 출력합니다. 375
# 숫자를 출력합니다. 376
# 숫자를 출력합니다. 377
# 숫자를 출력합니다. 378
# 숫자를 출력합니다. 379
# 숫자를 출력합니다. 380
# 숫자를 출력합니다. 381
# 숫자를 출력합니다. 382
# 숫자를 출력합니다. 383
# 숫자를 출력합니다. 384
# 숫자를 출력합니다. 385
# 숫자를 출력합니다. 386
# 숫자를 출력합니다. 387
# 숫자를 출력합니다. 388
# 숫자를 출력합니다. 389
# 숫자를 출력합니다. 390
# 숫자를 출력합니다. 391
# 숫자를 출력합니다. 392
# 숫자를 출력합니다. 393
# 숫자를 출력합니다. 394
# 숫자를 출력합니다. 395
# 숫자를 출력합니다. 396
# 숫자를 출력합니다. 397
# 숫자를 출력합니다. 398
# 숫자를 출력합니다. 399
# 숫자를 출력합니다. 400
# 숫자를 출력합니다. 401
# 숫자를 출력합니다. 402
# 숫자를 출력합니다. 403
# 숫자를 출력합니다. 404
# 숫자를 출력합니다. 405
# 숫자를 출력합니다. 406
# 숫자를 출력합니다. 407
# 숫자를 출력합니다. 408
# 숫자를 출력합니다. 409
# 숫자를 출력합니다. 410
# 숫자를 출력합니다. 411
# 숫자를 출력합니다. 412
# 숫자를 출력합니다. 413
# 숫자를 출력합니다. 414
# 숫자를 출력합니다. 415
# 숫자를 출력합니다. 416
# 숫자를 출력합니다. 417
# 숫자를 출력합니다. 418
# 숫자를 출력합니다. 419
# 숫자를 출력합니다. 420
# 숫자를 출력합니다. 421
# 숫자를 출력합니다. 422
# 숫자를 출력합니다. 423
# 숫자를 출력합니다. 424
# 숫자를 출력합니다. 425
# 숫자를 출력합니다. 426
# 숫자를 출력합니다. 427
# 숫자를 출력합니다. 428
# 숫자를 출력합니다. 429
# 숫자를 출력합니다. 430
# 숫자를 출력합니다. 431
# 숫자를 출력합니다. 432
# 숫자를 출력합니다. 433
# 숫자를 출력합니다. 434
# 숫자를 출력합니다. 435
# 숫자를 출력합니다. 436
# 숫자를 출력합니다. 437
# 숫자를 출력합니다. 438
# 숫자를 출력합니다. 439
# 숫자를 출력합니다. 440
# 숫자를 출력합니다. 441
# 숫자를 출력합니다. 442
# 숫자를 출력합니다. 443
# 숫자를 출력합니다. 444
# 숫자를 출력합니다. 445
# 숫자를 출력합니다. 446
# 숫자를 출력합니다. 447
# 숫자를 출력합니다. 448
# 숫자를 출력합니다. 449
# 숫자를 출력합니다. 450
# 숫자를 출력합니다. 451
# 숫자를 출력합니다. 452
# 숫자를 출력합니다. 453
# 숫자를 출력합니다. 454
# 숫자를 출력합니다. 455
# 숫자를 출력합니다. 456
# 숫자를 출력합니다. 457
# 숫자를 출력합니다. 458
# 숫자를 출력합니다. 459
# 숫자를 출력합니다. 460
# 숫자를 출력합니다. 461
# 숫자를 출력합니다. 462
# 숫자를 출력합니다. 463
# 숫자를 출력합니다. 464
# 숫자를 출력합니다. 465
# 숫자를 출력합니다. 466
# 숫자를 출력합니다. 467
# 숫자를 출력합니다. 468
# 숫자를 출력합니다. 469
# 숫자를 출력합니다. 470
# 숫자를 출력합니다. 471
# 숫자를 출력합니다. 472
# 숫자를 출력합니다. 473
# 숫자를 출력합니다. 474
# 숫자를 출력합니다. 475
# 숫자를 출력합니다. 476
# 숫자를 출력합니다. 477
# 숫자를 출력합니다. 478
# 숫자를 출력합니다. 479
# 숫자를 출력합니다. 480
# 숫자를 출력합니다. 481
# 숫자를 출력합니다. 482
# 숫자를 출력합니다. 483
# 숫자를 출력합니다. 484
# 숫자를 출력합니다. 485
# 숫자를 출력합니다. 486
# 숫자를 출력합니다. 487
# 숫자를 출력합니다. 488
# 숫자를 출력합니다. 489
# 숫자를 출력합니다. 490
# 숫자를 출력합니다. 491
# 숫자를 출력합니다. 492
# 숫자를 출력합니다. 493
# 숫자를 출력합니다. 494
# 숫자를 출력합니다. 495
# 숫자를 출력합니다. 496
# 숫자를 출력합니다. 497
# 숫자를 출력합니다. 498
# 숫자를 출력합니다. 499
# 숫자를 출력합니다. 500
# 숫자를 출력합니다. 501
# 숫자를 출력합니다. 502
# 숫자를 출력합니다. 503
# 숫자를 출력합니다. 504
# 숫자를 출력합니다. 505
# 숫자를 출력합니다. 506
# 숫자를 출력합니다. 507
# 숫자를 출력합니다. 508
# 숫자를 출력합니다. 509
# 숫자를 출력합니다. 510
# 숫자를 출력합니다. 511
# 숫자를 출력합니다. 512
# 숫자를 출력합니다. 513
# 숫자를 출력합니다. 514
# 숫자를 출력합니다. 515
# 숫자를 출력합니다. 516
# 숫자를 출력합니다. 517
# 숫자를 출력합니다. 518
# 숫자를 출력합니다. 519
# 숫자를 출력합니다. 520
# 숫자를 출력합니다. 521
# 숫자를 출력합니다. 522
# 숫자를 출력합니다. 523
# 숫자를 출력합니다. 524
# 숫자를 출력합니다. 525
# 숫자를 출력합니다. 526
# 숫자를 출력합니다. 527
# 숫자를 출력합니다. 528
# 숫자를 출력합니다. 529
# 숫자를 출력합니다. 530
# 숫자를 출력합니다. 531
# 숫자를 출력합니다. 532
# 숫자를 출력합니다. 533
# 숫자를 출력합니다. 534
# 숫자를 출력합니다. 535
# 숫자를 출력합니다. 536
# 숫자를 출력합니다. 537
# 숫자를 출력합니다. 538
# 숫자를 출력합니다. 539
# 숫자를 출력합니다. 540
# 숫자를 출력합니다. 541
# 숫자를 출력합니다. 542
# 숫자를 출력합니다. 543
# 숫자를 출력합니다. 544
# 숫자를 출력합니다. 545
# 숫자를 출력합니다. 546
# 숫자를 출력합니다. 547
# 숫자를 출력합니다. 548
# 숫자를 출력합니다. 549
# 숫자를 출력합니다. 550
# 숫자를 출력합니다. 551
# 숫자를 출력합니다. 552
# 숫자를 출력합니다. 553
# 숫자를 출력합니다. 554
# 숫자를 출력합니다. 555
# 숫자를 출력합니다. 556
# 숫자를 출력합니다. 557
# 숫자를 출력합니다. 558
# 숫자를 출력합니다. 559
# 숫자를 출력합니다. 560
# 숫자를 출력합니다. 561
# 숫자를 출력합니다. 562
# 숫자를 출력합니다. 563
# 숫자를 출력합니다. 564
# 숫자를 출력합니다. 565
# 숫자를 출력합니다. 566
# 숫자를 출력합니다. 567
# 숫자를 출력합니다. 568
# 숫자를 출력합니다. 569
# 숫자를 출력합니다. 570
# 숫자를 출력합니다. 571
# 숫자를 출력합니다. 572
# 숫자를 출력합니다. 573
# 숫자를 출력합니다. 574
# 숫자를 출력합니다. 575
# 숫자를 출력합니다. 576
# 숫자를 출력합니다. 577
# 숫자를 출력합니다. 578
# 숫자를 출력합니다. 579
# 숫자를 출력합니다. 580
# 숫자를 출력합니다. 581
# 숫자를 출력합니다. 582
# 숫자를 출력합니다. 583
# 숫자를 출력합니다. 584
# 숫자를 출력합니다. 585
# 숫자를 출력합니다. 586
# 숫자를 출력합니다. 587
# 숫자를 출력합니다. 588
# 숫자를 출력합니다. 589
# 숫자를 출력합니다. 590
# 숫자를 출력합니다. 591
# 숫자를 출력합니다. 592
# 숫자를 출력합니다. 593
# 숫자를 출력합니다. 594
# 숫자를 출력합니다. 595
# 숫자를 출력합니다. 596
# 숫자를 출력합니다. 597
# 숫자를 출력합니다. 598
# 숫자를 출력합니다. 599
# 숫자를 출력합니다. 600
# 숫자를 출력합니다. 601
# 숫자를 출력합니다. 602
# 숫자를 출력합니다. 603
# 숫자를 출력합니다. 604
# 숫자를 출력합니다. 605
# 숫자를 출력합니다. 606
# 숫자를 출력합니다. 607
# 숫자를 출력합니다. 608
# 숫자를 출력합니다. 609
# 숫자를 출력합니다. 610
# 숫자를 출력합니다. 611
# 숫자를 출력합니다. 612
# 숫자를 출력합니다. 613
# 숫자를 출력합니다. 614
# 숫자를 출력합니다. 615
# 숫자를 출력합니다. 616
# 숫자를 출력합니다. 617
# 숫자를 출력합니다. 618
# 숫자를 출력합니다. 619
# 숫자를 출력합니다. 620
# 숫자를 출력합니다. 621
# 숫자를 출력합니다. 622
# 숫자를 출력합니다. 623
# 숫자를 출력합니다. 624
# 숫자를 출력합니다. 625
# 숫자를 출력합니다. 626
# 숫자를 출력합니다. 627
# 숫자를 출력합니다. 628
# 숫자를 출력합니다. 629
# 숫자를 출력합니다. 630
# 숫자를 출력합니다. 631
# 숫자를 출력합니다. 632
# 숫자를 출력합니다. 633
# 숫자를 출력합니다. 634
# 숫자를 출력합니다. 635
# 숫자를 출력합니다. 636
# 숫자를 출력합니다. 637
# 숫자를 출력합니다. 638
# 숫자를 출력합니다. 639
# 숫자를 출력합니다. 640
# 숫자를 출력합니다. 641
# 숫자를 출력합니다. 642
# 숫자를 출력합니다. 643
# 숫자를 출력합니다. 644
# 숫자를 출력합니다. 645
# 숫자를 출력합니다. 646
# 숫자를 출력합니다. 647
# 숫자를 출력합니다. 648
# 숫자를 출력합니다. 649
# 숫자를 출력합니다. 650
# 숫자를 출력합니다. 651
# 숫자를 출력합니다. 652
# 숫자를 출력합니다. 653
# 숫자를 출력합니다. 654
# 숫자를 출력합니다. 655
# 숫자를 출력합니다. 656
# 숫자를 출력합니다. 657
# 숫자를 출력합니다. 658
# 숫자를 출력합니다. 659
# 숫자를 출력합니다. 660
# 숫자를 출력합니다. 661
# 숫자를 출력합니다. 662
# 숫자를 출력합니다. 663
# 숫자를 출력합니다. 664
# 숫자를 출력합니다. 665
# 숫자를 출력합니다. 666
# 숫자를 출력합니다. 667
# 숫자를 출력합니다. 668
# 숫자를 출력합니다. 669
# 숫자를 출력합니다. 670
# 숫자를 출력합니다. 671
# 숫자를 출력합니다. 672
# 숫자를 출력합니다. 673
# 숫자를 출력합니다. 674
# 숫자를 출력합니다. 675
# 숫자를 출력합니다. 676
# 숫자를 출력합니다. 677
# 숫자를 출력합니다. 678
# 숫자를 출력합니다. 679
# 숫자를 출력합니다. 680
# 숫자를 출력합니다. 681
# 숫자를 출력합니다. 682
# 숫자를 출력합니다. 683
# 숫자를 출력합니다. 684
# 숫자를 출력합니다. 685
# 숫자를 출력합니다. 686
# 숫자를 출력합니다. 687
# 숫자를 출력합니다. 688
# 숫자를 출력합니다. 689
# 숫자를 출력합니다. 690
# 숫자를 출력합니다. 691
# 숫자를 출력합니다. 692
# 숫자를 출력합니다. 693
# 숫자를 출력합니다. 694
# 숫자를 출력합니다. 695
# 숫자를 출력합니다. 696
# 숫자를 출력합니다. 697
# 숫자를 출력합니다. 698
# 숫자를 출력합니다. 699
# 숫자를 출력합니다. 700
# 숫자를 출력합니다. 701
# 숫자를 출력합니다. 702
# 숫자를 출력합니다. 703
# 숫자를 출력합니다. 704
# 숫자를 출력합니다. 705
# 숫자를 출력합니다. 706
# 숫자를 출력합니다. 707
# 숫자를 출력합니다. 708
# 숫자를 출력합니다. 709
# 숫자를 출력합니다. 710
# 숫자를 출력합니다. 711
# 숫자를 출력합니다. 712
# 숫자를 출력합니다. 713
# 숫자를 출력합니다. 714
# 숫자를 출력합니다. 715
# 숫자를 출력합니다. 716
# 숫자를 출력합니다. 717
# 숫자를 출력합니다. 718
# 숫자를 출력합니다. 719
# 숫자를 출력합니다. 720
# 숫자를 출력합니다. 721
# 숫자를 출력합니다. 722
# 숫자를 출력합니다. 723
# 숫자를 출력합니다. 724
# 숫자를 출력합니다. 725
# 숫자를 출력합니다. 726
# 숫자를 출력합니다. 727
# 숫자를 출력합니다. 728
# 숫자를 출력합니다. 729
# 숫자를 출력합니다. 730
# 숫자를 출력합니다. 731
# 숫자를 출력합니다. 732
# 숫자를 출력합니다. 733
# 숫자를 출력합니다. 734
# 숫자를 출력합니다. 735
# 숫자를 출력합니다. 736
# 숫자를 출력합니다. 737
# 숫자를 출력합니다. 738
# 숫자를 출력합니다. 739
# 숫자를 출력합니다. 740
# 숫자를 출력합니다. 741
# 숫자를 출력합니다. 742
# 숫자를 출력합니다. 743
# 숫자를 출력합니다. 744
# 숫자를 출력합니다. 745
# 숫자를 출력합니다. 746
# 숫자를 출력합니다. 747
# 숫자를 출력합니다. 748
# 숫자를 출력합니다. 749
# 숫자를 출력합니다. 750
# 숫자를 출력합니다. 751
# 숫자를 출력합니다. 752
# 숫자를 출력합니다. 753
# 숫자를 출력합니다. 754
# 숫자를 출력합니다. 755
# 숫자를 출력합니다. 756
# 숫자를 출력합니다. 757
# 숫자를 출력합니다. 758
# 숫자를 출력합니다. 759
# 숫자를 출력합니다. 760
# 숫자를 출력합니다. 761
# 숫자를 출력합니다. 762
# 숫자를 출력합니다. 763
# 숫자를 출력합니다. 764
# 숫자를 출력합니다. 765
# 숫자를 출력합니다. 766
# 숫자를 출력합니다. 767
# 숫자를 출력합니다. 768
# 숫자를 출력합니다. 769
# 숫자를 출력합니다. 770
# 숫자를 출력합니다. 771
# 숫자를 출력합니다. 772
# 숫자를 출력합니다. 773
# 숫자를 출력합니다. 774
# 숫자를 출력합니다. 775
# 숫자를 출력합니다. 776
# 숫자를 출력합니다. 777
# 숫자를 출력합니다. 778
# 숫자를 출력합니다. 779
# 숫자를 출력합니다. 780
# 숫자를 출력합니다. 781
# 숫자를 출력합니다. 782
# 숫자를 출력합니다. 783
# 숫자를 출력합니다. 784
# 숫자를 출력합니다. 785
# 숫자를 출력합니다. 786
# 숫자를 출력합니다. 787
# 숫자를 출력합니다. 788
# 숫자를 출력합니다. 789
# 숫자를 출력합니다. 790
# 숫자를 출력합니다. 791
# 숫자를 출력합니다. 792
# 숫자를 출력합니다. 793
# 숫자를 출력합니다. 794
# 숫자를 출력합니다. 795
# 숫자를 출력합니다. 796
# 숫자를 출력합니다. 797
# 숫자를 출력합니다. 798
# 숫자를 출력합니다. 799
# 숫자를 출력합니다. 800
# 숫자를 출력합니다. 801
# 숫자를 출력합니다. 802
# 숫자를 출력합니다. 803
# 숫자를 출력합니다. 804
# 숫자를 출력합니다. 805
# 숫자를 출력합니다. 806
# 숫자를 출력합니다. 807
# 숫자를 출력합니다. 808
# 숫자를 출력합니다. 809
# 숫자를 출력합니다. 810
# 숫자를 출력합니다. 811
# 숫자를 출력합니다. 812
# 숫자를 출력합니다. 813
# 숫자를 출력합니다. 814
# 숫자를 출력합니다. 815
# 숫자를 출력합니다. 816
# 숫자를 출력합니다. 817
# 숫자를 출력합니다. 818
# 숫자를 출력합니다. 819
# 숫자를 출력합니다. 820
# 숫자를 출력합니다. 821
# 숫자를 출력합니다. 822
# 숫자를 출력합니다. 823
# 숫자를 출력합니다. 824
# 숫자를 출력합니다. 825
# 숫자를 출력합니다. 826
# 숫자를 출력합니다. 827
# 숫자를 출력합니다. 828
# 숫자를 출력합니다. 829
# 숫자를 출력합니다. 830
# 숫자를 출력합니다. 831
# 숫자를 출력합니다. 832
# 숫자를 출력합니다. 833
# 숫자를 출력합니다. 834
# 숫자를 출력합니다. 835
# 숫자를 출력합니다. 836
# 숫자를 출력합니다. 837
# 숫자를 출력합니다. 838
# 숫자를 출력합니다. 839
# 숫자를 출력합니다. 840
# 숫자를 출력합니다. 841
# 숫자를 출력합니다. 842
# 숫자를 출력합니다. 843
# 숫자를 출력합니다. 844
# 숫자를 출력합니다. 845
# 숫자를 출력합니다. 846
# 숫자를 출력합니다. 847
# 숫자를 출력합니다. 848
# 숫자를 출력합니다. 849
# 숫자를 출력합니다. 850
# 숫자를 출력합니다. 851
# 숫자를 출력합니다. 852
# 숫자를 출력합니다. 853
# 숫자를 출력합니다. 854
# 숫자를 출력합니다. 855
# 숫자를 출력합니다. 856
# 숫자를 출력합니다. 857
# 숫자를 출력합니다. 858
# 숫자를 출력합니다. 859
# 숫자를 출력합니다. 860
# 숫자를 출력합니다. 861
# 숫자를 출력합니다. 862
# 숫자를 출력합니다. 863
# 숫자를 출력합니다. 864
# 숫자를 출력합니다. 865
# 숫자를 출력합니다. 866
# 숫자를 출력합니다. 867
# 숫자를 출력합니다. 868
# 숫자를 출력합니다. 869
# 숫자를 출력합니다. 870
# 숫자를 출력합니다. 871
# 숫자를 출력합니다. 872
# 숫자를 출력합니다. 873
# 숫자를 출력합니다. 874
# 숫자를 출력합니다. 875
# 숫자를 출력합니다. 876
# 숫자를 출력합니다. 877
# 숫자를 출력합니다. 878
# 숫자를 출력합니다. 879
# 숫자를 출력합니다. 880
# 숫자를 출력합니다. 881
# 숫자를 출력합니다. 882
# 숫자를 출력합니다. 883
# 숫자를 출력합니다. 884
# 숫자를 출력합니다. 885
# 숫자를 출력합니다. 886
# 숫자를 출력합니다. 887
# 숫자를 출력합니다. 888
# 숫자를 출력합니다. 889
# 숫자를 출력합니다. 890
# 숫자를 출력합니다. 891
# 숫자를 출력합니다. 892
# 숫자를 출력합니다. 893
# 숫자를 출력합니다. 894
# 숫자를 출력합니다. 895
# 숫자를 출력합니다. 896
# 숫자를 출력합니다. 897
# 숫자를 출력합니다. 898
# 숫자를 출력합니다. 899
# 숫자를 출력합니다. 900
# 숫자를 출력합니다. 901
# 숫자를 출력합니다. 902
# 숫자를 출력합니다. 903
# 숫자를 출력합니다. 904
# 숫자를 출력합니다. 905
# 숫자를 출력합니다. 906
# 숫자를 출력합니다. 907
# 숫자를 출력합니다. 908
# 숫자를 출력합니다. 909
# 숫자를 출력합니다. 910
# 숫자를 출력합니다. 911
# 숫자를 출력합니다. 912
# 숫자를 출력합니다. 913
# 숫자를 출력합니다. 914
# 숫자를 출력합니다. 915
# 숫자를 출력합니다. 916
# 숫자를 출력합니다. 917
# 숫자를 출력합니다. 918
# 숫자를 출력합니다. 919
# 숫자를 출력합니다. 920
# 숫자를 출력합니다. 921
# 숫자를 출력합니다. 922
# 숫자를 출력합니다. 923
# 숫자를 출력합니다. 924
# 숫자를 출력합니다. 925
# 숫자를 출력합니다. 926
# 숫자를 출력합니다. 927
# 숫자를 출력합니다. 928
# 숫자를 출력합니다. 929
# 숫자를 출력합니다. 930
# 숫자를 출력합니다. 931
# 숫자를 출력합니다. 932
# 숫자를 출력합니다. 933
# 숫자를 출력합니다. 934
# 숫자를 출력합니다. 935
# 숫자를 출력합니다. 936
# 숫자를 출력합니다. 937
# 숫자를 출력합니다. 938
# 숫자를 출력합니다. 939
# 숫자를 출력합니다. 940
# 숫자를 출력합니다. 941
# 숫자를 출력합니다. 942
# 숫자를 출력합니다. 943
# 숫자를 출력합니다. 944
# 숫자를 출력합니다. 945
# 숫자를 출력합니다. 946
# 숫자를 출력합니다. 947
# 숫자를 출력합니다. 948
# 숫자를 출력합니다. 949
# 숫자를 출력합니다. 950
# 숫자를 출력합니다. 951
# 숫자를 출력합니다. 952
# 숫자를 출력합니다. 953
# 숫자를 출력합니다. 954
# 숫자를 출력합니다. 955
# 숫자를 출력합니다. 956
# 숫자를 출력합니다. 957
# 숫자를 출력합니다. 958
# 숫자를 출력합니다. 959
# 숫자를 출력합니다. 960
# 숫자를 출력합니다. 961
# 숫자를 출력합니다. 962
# 숫자를 출력합니다. 963
# 숫자를 출력합니다. 964
# 숫자를 출력합니다. 965
# 숫자를 출력합니다. 966
# 숫자를 출력합니다. 967
# 숫자를 출력합니다. 968
# 숫자를 출력합니다. 969
# 숫자를 출력합니다. 970
# 숫자를 출력합니다. 971
# 숫자를 출력합니다. 972
# 숫자를 출력합니다. 973
# 숫자를 출력합니다. 974
# 숫자를 출력합니다. 975
# 숫자를 출력합니다. 976
# 숫자를 출력합니다. 977
# 숫자를 출력합니다. 978
# 숫자를 출력합니다. 979
# 숫자를 출력합니다. 980
# 숫자를 출력합니다. 981
# 숫자를 출력합니다. 982
# 숫자를 출력합니다. 983
# 숫자를 출력합니다. 984
# 숫자를 출력합니다. 985
# 숫자를 출력합니다. 986
# 숫자를 출력합니다. 987
# 숫자를 출력합니다. 988
# 숫자를 출력합니다. 989
# 숫자를 출력합니다. 990
# 숫자를 출력합니다. 991
# 숫자를 출력합니다. 992
# 숫자를 출력합니다. 993
# 숫자를 출력합니다. 994
# 숫자를 출력합니다. 995
# 숫자를 출력합니다. 996
# 숫자를 출력합니다. 997
# 숫자를 출력합니다. 998
# 숫자를 출력합니다. 999
# 프로그램을 수행하는데 0.03882071100000051초가 걸렸습니다

# %%
# 반복문 기초 - 문자열 

for i in 'python':
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in ['python','numpy','pandas']:
  print(i)
# Out:
# python
# numpy
# pandas

# %%
# 반복문 기초 7 - 딕셔너리

d = {"key1" : 1000 , "key2" : 2000, "key3" : 3000}
for i in d.keys():
  print("출력된 문자는", i, "입니다.")

print()

# 반복문 기초 7 - 딕셔너리

d = {"key1" : 1000 , "key2" : 2000, "key3" : 3000}
for i in d.values():
  print("출력된 문자는", i, "입니다.")

print()
# 반복문 기초 7 - 딕셔너리

d = {"key1" : 1000 , "key2" : 2000, "key3" : 3000}
for i in d.items():
  print("출력된 문자는", i, "입니다.")
# Out:
# 출력된 문자는 key1 입니다.
# 출력된 문자는 key2 입니다.
# 출력된 문자는 key3 입니다.
#
# 출력된 문자는 1000 입니다.
# 출력된 문자는 2000 입니다.
# 출력된 문자는 3000 입니다.
#
# 출력된 문자는 ('key1', 1000) 입니다.
# 출력된 문자는 ('key2', 2000) 입니다.
# 출력된 문자는 ('key3', 3000) 입니다.

# %%
# for, else 예제
# 5마리를 잡으면 배가 꽉 차는 상황 


for i in range(100):
  print(f"{i} 물고기를 잡았습니다.")

  if i == 5:
    print('만선입니다. 물고기를 다 잡았습니다.')
    break # 더 이상 문장을 실행하지 않고, 종료 
else:
  print("아직 여유가 있어... 만족하고 돌아갑시다.")
print("수고하셨습니다.")
# Out:
# 0 물고기를 잡았습니다.
# 1 물고기를 잡았습니다.
# 2 물고기를 잡았습니다.
# 3 물고기를 잡았습니다.
# 4 물고기를 잡았습니다.
# 5 물고기를 잡았습니다.
# 만선입니다. 물고기를 다 잡았습니다.
# 수고하셨습니다.

# %%
for i in range(5):
  print(f"{i} 물고기를 잡았습니다.")

  if i == 5:
    print('만선입니다. 물고기를 다 잡았습니다.')
    break # 더 이상 문장을 실행하지 않고, 종료 
else:
  print("아직 여유가 있어... 만족하고 돌아갑시다.")
print("수고하셨습니다.")
# Out:
# 0 물고기를 잡았습니다.
# 1 물고기를 잡았습니다.
# 2 물고기를 잡았습니다.
# 3 물고기를 잡았습니다.
# 4 물고기를 잡았습니다.
# 아직 여유가 있어... 만족하고 돌아갑시다.
# 수고하셨습니다.

# %%
l = [0, 3, -1, 10]

for x in l:
  if x < 0:
    print("음수가 발견되었습니다. 프로그램을 종료합니다.")
    break
else:
  print("음수를 발견하지 못했습니다.")
# Out:
# 음수가 발견되었습니다. 프로그램을 종료합니다.

# %%
# 반복문 기초 break -- continue 

# 반복 출력
 
for i in range(10):
  
  if i == 3:
    break
  
  if i == 1:
    continue

print(i) # 3이 출력됨
# Out:
# 3

# %%
for i in range(10): 

  if i == 3:
    break 

  if i == 1: 
    continue
  
  print(i) #0,2
# Out:
# 0
# 2

# %%
# 이중 반복문 

# 구구단 만들기 

for i in range(1,10):
  for j in range(1,10):
    print(f"{i}X{j} = {i*j} ")
  print('-'*10)
# Out:
# 1X1 = 1
# 1X2 = 2
# 1X3 = 3
# 1X4 = 4
# 1X5 = 5
# 1X6 = 6
# 1X7 = 7
# 1X8 = 8
# 1X9 = 9
# ----------
# 2X1 = 2
# 2X2 = 4
# 2X3 = 6
# 2X4 = 8
# 2X5 = 10
# 2X6 = 12
# 2X7 = 14
# 2X8 = 16
# 2X9 = 18
# ----------
# 3X1 = 3
# 3X2 = 6
# 3X3 = 9
# 3X4 = 12
# 3X5 = 15
# 3X6 = 18
# 3X7 = 21
# 3X8 = 24
# 3X9 = 27
# ----------
# 4X1 = 4
# 4X2 = 8
# 4X3 = 12
# 4X4 = 16
# 4X5 = 20
# 4X6 = 24
# 4X7 = 28
# 4X8 = 32
# 4X9 = 36
# ----------
# 5X1 = 5
# 5X2 = 10
# 5X3 = 15
# 5X4 = 20
# 5X5 = 25
# 5X6 = 30
# 5X7 = 35
# 5X8 = 40
# 5X9 = 45
# ----------
# 6X1 = 6
# 6X2 = 12
# 6X3 = 18
# 6X4 = 24
# 6X5 = 30
# 6X6 = 36
# 6X7 = 42
# 6X8 = 48
# 6X9 = 54
# ----------
# 7X1 = 7
# 7X2 = 14
# 7X3 = 21
# 7X4 = 28
# 7X5 = 35
# 7X6 = 42
# 7X7 = 49
# 7X8 = 56
# 7X9 = 63
# ----------
# 8X1 = 8
# 8X2 = 16
# 8X3 = 24
# 8X4 = 32
# 8X5 = 40
# 8X6 = 48
# 8X7 = 56
# 8X8 = 64
# 8X9 = 72
# ----------
# 9X1 = 9
# 9X2 = 18
# 9X3 = 27
# 9X4 = 36
# 9X5 = 45
# 9X6 = 54
# 9X7 = 63
# 9X8 = 72
# 9X9 = 81
# ----------

# %%
# 리스트 컴프리헨션

# 예제 1)
'''
list_i = []

for i in range(1,10):
  list_i.append(i)

print(list_i)
'''

x = [i for i in range(1,10)] # 위의 for문과 같은 결과를 출력한다 
print(x)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# 리스트 반복문 예제 2 

y = [f"{i} * {j} = {i * j}" for i in range(1,10) for j in range(1,10)]

y
# Out:
# ['1 * 1 = 1',
#  '1 * 2 = 2',
#  '1 * 3 = 3',
#  '1 * 4 = 4',
#  '1 * 5 = 5',
#  '1 * 6 = 6',
#  '1 * 7 = 7',
#  '1 * 8 = 8',
#  '1 * 9 = 9',
#  '2 * 1 = 2',
#  '2 * 2 = 4',
#  '2 * 3 = 6',
#  '2 * 4 = 8',
#  '2 * 5 = 10',
#  '2 * 6 = 12',
#  '2 * 7 = 14',
#  '2 * 8 = 16',
#  '2 * 9 = 18',
#  '3 * 1 = 3',
#  '3 * 2 = 6',
#  '3 * 3 = 9',
#  '3 * 4 = 12',
#  '3 * 5 = 15',
#  '3 * 6 = 18',
#  '3 * 7 = 21',
#  '3 * 8 = 24',
#  '3 * 9 = 27',
#  '4 * 1 = 4',
#  '4 * 2 = 8',
#  '4 * 3 = 12',
#  '4 * 4 = 16',
#  '4 * 5 = 20',
#  '4 * 6 = 24',
#  '4 * 7 = 28',
#  '4 * 8 = 32',
#  '4 * 9 = 36',
#  '5 * 1 = 5',
#  '5 * 2 = 10',
#  '5 * 3 = 15',
#  '5 * 4 = 20',
#  '5 * 5 = 25',
#  '5 * 6 = 30',
#  '5 * 7 = 35',
#  '5 * 8 = 40',
#  '5 * 9 = 45',
#  '6 * 1 = 6',
#  '6 * 2 = 12',
#  '6 * 3 = 18',
#  '6 * 4 = 24',
#  '6 * 5 = 30',
#  '6 * 6 = 36',
#  '6 * 7 = 42',
#  '6 * 8 = 48',
#  '6 * 9 = 54',
#  '7 * 1 = 7',
#  '7 * 2 = 14',
#  '7 * 3 = 21',
#  '7 * 4 = 28',
#  '7 * 5 = 35',
#  '7 * 6 = 42',
#  '7 * 7 = 49',
#  '7 * 8 = 56',
#  '7 * 9 = 63',
#  '8 * 1 = 8',
#  '8 * 2 = 16',
#  '8 * 3 = 24',
#  '8 * 4 = 32',
#  '8 * 5 = 40',
#  '8 * 6 = 48',
#  '8 * 7 = 56',
#  '8 * 8 = 64',
#  '8 * 9 = 72',
#  '9 * 1 = 9',
#  '9 * 2 = 18',
#  '9 * 3 = 27',
#  '9 * 4 = 36',
#  '9 * 5 = 45',
#  '9 * 6 = 54',
#  '9 * 7 = 63',
#  '9 * 8 = 72',
#  '9 * 9 = 81']

# %%
# 반복문 예제 

def sumthingFuncthing(i):
  if i % 100 == 0:
    return i
  else:
    return 0

# %%
old_list = [100,200,300,101,202,303]

new_list = [sumthingFuncthing(i) for i in old_list]

print(sum(new_list))
# Out:
# 600

# %%
# 다중인자 리스트 순회

# 다중 리스트 for문

skill = [
        ('고기잡이', 100, 300),
         ('고기팔기', 120, 400),
         ('낚시', 5, 500),
         ('통발', 5, 600),
         ('큰그물', 5, 700)
]

for i, j, z in skill:
  print(i, j, z)
# Out:
# 고기잡이 100 300
# 고기팔기 120 400
# 낚시 5 500
# 통발 5 600
# 큰그물 5 700

# %%
#[In]

# enumerate

skill = [
        ('고기잡이', 100, 'SS'),
        ('고기팔기', 120, 'SSS'),
        ('낚시', 5, 'C'),
        ('통발', 5, 'C'),
        ('큰그물', 5, 'C')
]

for i, (skillName, skillLevel, skillGrade) in enumerate(skill):
    print(i, skillName, skillLevel, skillGrade)
# Out:
# 0 고기잡이 100 SS
# 1 고기팔기 120 SSS
# 2 낚시 5 C
# 3 통발 5 C
# 4 큰그물 5 C

# %%
for i, j in enumerate(skill, 100):
  print(i, j)
# Out:
# 100 ('고기잡이', 100, 'SS')
# 101 ('고기팔기', 120, 'SSS')
# 102 ('낚시', 5, 'C')
# 103 ('통발', 5, 'C')
# 104 ('큰그물', 5, 'C')

# %%
# 반복문 연습 문제 1 

for a in range(8):
  a += 1 
print(a)
# Out:
# 8

# %%
# 반복문 연습 문제 2 
for a in range(8):
  a *= (a-1)
print(a)
# Out:
# 42

# %%
# 반복문 연습 문제 3 

for a in range(8):
  a += a # a = a + a
print(a)
# Out:
# 14

# %%
# 반복문 연습 문제 4

for a in range(8):
  a *= 1
print(a)
# Out:
# 7

# %%
# 반복문 문제 5
# 변수 age의 자료형이 정수형일때 숫자 문자형일때 문자가 출력되는 코드

ages = ['one', 8, 'twenty', 40]

for age in ages:
  if type(age) == int:
    print(age, '숫자')
  else:
    print(age, '문자')
# Out:
# one 문자
# 8 숫자
# twenty 문자
# 40 숫자

# %%
#1부터 10까지 짝수를 뽑으려면 어떤 코드를 작성해야할까요? : a < 11  

a = 1

while a < 11:
  if a % 2 == 0:
    print(a)
    a += 1
  else:
    a += 1
  
  if a == 0:
    break
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# while문 예제 

숫자 = 0 

while True:
  print("현재 숫자는", 숫자, "입니다.")
  숫자 += 1 
  if 숫자 > 5:
    print("반복문을 종료합니다")
    break # break를 넣지 않으면 무한 루프에 빠진다
# Out:
# 현재 숫자는 0 입니다.
# 현재 숫자는 1 입니다.
# 현재 숫자는 2 입니다.
# 현재 숫자는 3 입니다.
# 현재 숫자는 4 입니다.
# 현재 숫자는 5 입니다.
# 반복문을 종료합니다

# %%
# while else 

숫자 = 0 

while 숫자 < 5:
  print("현재 숫자는", 숫자, "입니다.")
  숫자 += 1 
else:
  print("반복문을 종료합니다.")
# Out:
# 현재 숫자는 0 입니다.
# 현재 숫자는 1 입니다.
# 현재 숫자는 2 입니다.
# 현재 숫자는 3 입니다.
# 현재 숫자는 4 입니다.
# 반복문을 종료합니다.

# %%
시간 = 0
현재시간 = int(input("현재 시각을 입력하세요 : "))
종료시간 = 16 

if 현재시간 > 종료시간:
  print("수업이 끝났기 때문에 Q&A 시간을 가지겠습니다.")
else:
  while True:
    시간 += 1 
    현재시간 += 1 
    print(f"{시간}시간이 지나 {현재시간}이 되었습니다")

    if 현재시간 == 종료시간:
      print("수업 종료시간이 되었기 때문에 Q&A 시간을 가지겠습니다")
      break
# Out:
# 현재 시각을 입력하세요 : 15
# 1시간이 지나 16이 되었습니다
# 수업 종료시간이 되었기 때문에 Q&A 시간을 가지겠습니다

# %%
# 구구단 5단까지 출력 

for i in range(2, 10):
  for j in range(1, 10):
    if j > 5:
      break
    print(f"{i} * {j} = {i * j}")
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45

# %%
# continue 

count_amount= [
    (3, 15000),
    (5, 25000),
    (1, 5000),
    (8, 40000),
    (0, 0),
    (2, 10000)
]

for count, amount in count_amount:
  if count < 1 :
    continue
  print(f"구매개수는 {count}, 구매가격은 {amount}")
# Out:
# 구매개수는 3, 구매가격은 15000
# 구매개수는 5, 구매가격은 25000
# 구매개수는 1, 구매가격은 5000
# 구매개수는 8, 구매가격은 40000
# 구매개수는 2, 구매가격은 10000

# %%
# pass

구매개수_총가격= [
    (3, 15000),
    (5, 25000),
    (1, 5000),
    (8, 40000),
    (0, 0),
    (2, 10000)
    ]

for 구매개수, 총가격 in 구매개수_총가격:
  if 구매개수 < 1 :
    pass
  print('구매개수는 {}개이며 {}원입니다.'.format(구매개수, 총가격))
# Out:
# 구매개수는 3개이며 15000원입니다.
# 구매개수는 5개이며 25000원입니다.
# 구매개수는 1개이며 5000원입니다.
# 구매개수는 8개이며 40000원입니다.
# 구매개수는 0개이며 0원입니다.
# 구매개수는 2개이며 10000원입니다.

# %%
# while문으로 구구단 만들기 

i = 2 

while i < 10:
  k = 1 
  while k < 10:
      print(i, " * ", k, " = ", i * k)
      k += 1
  i += 1
# Out:
# 2  *  1  =  2
# 2  *  2  =  4
# 2  *  3  =  6
# 2  *  4  =  8
# 2  *  5  =  10
# 2  *  6  =  12
# 2  *  7  =  14
# 2  *  8  =  16
# 2  *  9  =  18
# 3  *  1  =  3
# 3  *  2  =  6
# 3  *  3  =  9
# 3  *  4  =  12
# 3  *  5  =  15
# 3  *  6  =  18
# 3  *  7  =  21
# 3  *  8  =  24
# 3  *  9  =  27
# 4  *  1  =  4
# 4  *  2  =  8
# 4  *  3  =  12
# 4  *  4  =  16
# 4  *  5  =  20
# 4  *  6  =  24
# 4  *  7  =  28
# 4  *  8  =  32
# 4  *  9  =  36
# 5  *  1  =  5
# 5  *  2  =  10
# 5  *  3  =  15
# 5  *  4  =  20
# 5  *  5  =  25
# 5  *  6  =  30
# 5  *  7  =  35
# 5  *  8  =  40
# 5  *  9  =  45
# 6  *  1  =  6
# 6  *  2  =  12
# 6  *  3  =  18
# 6  *  4  =  24
# 6  *  5  =  30
# 6  *  6  =  36
# 6  *  7  =  42
# 6  *  8  =  48
# 6  *  9  =  54
# 7  *  1  =  7
# 7  *  2  =  14
# 7  *  3  =  21
# 7  *  4  =  28
# 7  *  5  =  35
# 7  *  6  =  42
# 7  *  7  =  49
# 7  *  8  =  56
# 7  *  9  =  63
# 8  *  1  =  8
# 8  *  2  =  16
# 8  *  3  =  24
# 8  *  4  =  32
# 8  *  5  =  40
# 8  *  6  =  48
# 8  *  7  =  56
# 8  *  8  =  64
# 8  *  9  =  72
# 9  *  1  =  9
# 9  *  2  =  18
# 9  *  3  =  27
# 9  *  4  =  36
# 9  *  5  =  45
# 9  *  6  =  54
# 9  *  7  =  63
# 9  *  8  =  72
# 9  *  9  =  81

# %%
# 조건문 문제 

a = 1 

while a < 11:
  if a % 2 == 0:
    print(a)
    a += 1 
  else:
    a += 1 
  
  if a == 0:
    break
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# 조건문 문제
# 실행결과가 0인 코드를 작성하고 싶을때 어떻게 작성해야하는가?

money = 2000
snack = 500
water = 1000

while money != 0:
  if money > 1000:
    money -= water
  elif 0 < money <= 1000:
    money -= snack * 2 
#  else: 해당 구문은 없어도 됨 

print(money)
# Out:
# 0

# %%
# while문 예제 1 

i = 0 # 초기식

while i < 100: # 조건식
  print(i, '번째 출력') # 반복할 코드
  i += 1 # i를 1씩 증가

# %%
# while문 예제 2 - 입력하는 값 만큼 반복

count = int(input("반복할 횟수를 입력하세요 : "))

i = 0
while i < count: # i가 count보다 작을 때 반복 
  print(i, '번째 출력')
  i += 1
# Out:
# 반복할 횟수를 입력하세요 : 10
# 0 번째 출력
# 1 번째 출력
# 2 번째 출력
# 3 번째 출력
# 4 번째 출력
# 5 번째 출력
# 6 번째 출력
# 7 번째 출력
# 8 번째 출력
# 9 번째 출력

# %%
# while문 예제 3 - 맞을 때 까지 반복

import random # random 모듈을 가져옴 

i = 0

while i != 3: # 주사위 숫자가 3이 아닐 때 까지 반복 
  i = random.randint(1, 6) # randint를 사용하여 가상의 주사위 생성 
  print(i)
# Out:
# 5
# 2
# 4
# 6
# 2
# 1
# 6
# 2
# 3

# %%
# while문 예제 4 - 특정 데이터 제거

cust_all = [1,2,1,2,]
value = 1 

print(cust_all)

while value in cust_all:
  cust_all.remove(value)

print(cust_all)
# Out:
# [1, 2, 1, 2]
# [2, 2]

# %%
# 실습1. 1~100사이의 숫자를 맞출때까지 반복하는 while문을 작성해주시면 됩니다.
# 내가 입력한 숫자가 컴퓨터 숫자보다 작으면 "값이 작다"
# 내가 입력한 숫자가 컴퓨터 숫자보다 크면 "값이 크다"
# 답이 맞으면 맞았습니다. 


import random
guess_number = random.randint(1,100)
user_input = int(input("숫자를 입력해서 값을 맞춰보세요"))

while (user_input != guess_number):
  if user_input > guess_number:
    print("숫자가 큽니다.")
  else:
    print("숫자가 작습니다.")
  user_input = int(input("숫자를 입력해서 값을 다시 맞춰보세요"))
else:
  print("정답입니다.")
